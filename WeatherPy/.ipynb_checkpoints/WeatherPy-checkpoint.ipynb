# %%
#copied from starter code
#Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

import sys
import os

path = os.path.abspath("../Starter_Code/starter_code")
sys.path.append(path)
#Import the OpenWeatherMap API key
from api_keys import weather_api_key

#Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
#copied from starter code
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 618

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units=metric&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | hawaiian paradise park
# Processing Record 3 of Set 1 | binh long
# City not found. Skipping...
# Processing Record 4 of Set 1 | doganhisar
# Processing Record 5 of Set 1 | edinburgh of the seven seas
# Processing Record 6 of Set 1 | puerto natales
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | mejit
# Processing Record 9 of Set 1 | chakradharpur
# Processing Record 10 of Set 1 | harper
# Processing Record 11 of Set 1 | annau
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | klyuchi
# Processing Record 14 of Set 1 | badger
# Processing Record 15 of Set 1 | vila franca do campo
# Processing Record 16 of Set 1 | eforie sud
# Processing Record 17 of Set 1 | adamstown
# Processing Record 18 of Set 1 | kingston
# Processing Record 19 of Set 1 | crane
# Processing Record 20 of Set 1 | wuhu
# Processing Record 21 of Set 1 | blackmans bay
# Processing Record 22 of Set 1 | santa cruz
# Processing Record 23 of Set 1 | pandan
# Processing Record 24 of Set 1 | tangalle
# Processing Record 25 of Set 1 | port mathurin
# Processing Record 26 of Set 1 | mukah
# City not found. Skipping...
# Processing Record 27 of Set 1 | waingapu
# Processing Record 28 of Set 1 | nabire
# Processing Record 29 of Set 1 | hasaki
# Processing Record 30 of Set 1 | gwanda
# Processing Record 31 of Set 1 | porto franco
# Processing Record 32 of Set 1 | vernon
# Processing Record 33 of Set 1 | trondheim
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 1 | chonchi
# Processing Record 37 of Set 1 | smithers
# Processing Record 38 of Set 1 | wagar
# Processing Record 39 of Set 1 | kupang
# Processing Record 40 of Set 1 | tual
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | hamilton
# Processing Record 43 of Set 1 | la ronge
# Processing Record 44 of Set 1 | shanyang
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | nova sintra
# Processing Record 47 of Set 1 | newman
# Processing Record 48 of Set 1 | lerwick
# Processing Record 49 of Set 1 | pisco
# Processing Record 50 of Set 1 | keflavik
# Processing Record 0 of Set 2 | kutno
# Processing Record 1 of Set 2 | las heras
# Processing Record 2 of Set 2 | jose mariano jimenez
# City not found. Skipping...
# Processing Record 3 of Set 2 | kidal
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | ormara
# Processing Record 6 of Set 2 | tralee
# Processing Record 7 of Set 2 | tutoia
# Processing Record 8 of Set 2 | andergrove
# Processing Record 9 of Set 2 | anadyr
# Processing Record 10 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 11 of Set 2 | playa blanca
# Processing Record 12 of Set 2 | san antonio de pale
# Processing Record 13 of Set 2 | devinuwara
# City not found. Skipping...
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | porto novo
# Processing Record 16 of Set 2 | udachny
# Processing Record 17 of Set 2 | bardai
# Processing Record 18 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 19 of Set 2 | ondjiva
# Processing Record 20 of Set 2 | remire-montjoly
# Processing Record 21 of Set 2 | alaghsas
# Processing Record 22 of Set 2 | egilsstadir
# Processing Record 23 of Set 2 | trairi
# Processing Record 24 of Set 2 | tiksi
# Processing Record 25 of Set 2 | ta`u
# Processing Record 26 of Set 2 | wailua homesteads
# Processing Record 27 of Set 2 | ghadamis
# Processing Record 28 of Set 2 | hadibu
# Processing Record 29 of Set 2 | katabu
# Processing Record 30 of Set 2 | waitangi
# Processing Record 31 of Set 2 | isafjordur
# Processing Record 32 of Set 2 | kushiro
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | talnakh
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | dalbandin
# Processing Record 37 of Set 2 | invercargill
# Processing Record 38 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 39 of Set 2 | timmins
# Processing Record 40 of Set 2 | margaret river
# Processing Record 41 of Set 2 | west island
# Processing Record 42 of Set 2 | heroica caborca
# Processing Record 43 of Set 2 | dunedin
# Processing Record 44 of Set 2 | stanley
# Processing Record 45 of Set 2 | iskateley
# Processing Record 46 of Set 2 | bandundu
# Processing Record 47 of Set 2 | pacasmayo
# Processing Record 48 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 49 of Set 2 | novaya igirma
# Processing Record 0 of Set 3 | charcas
# Processing Record 1 of Set 3 | aasiaat
# Processing Record 2 of Set 3 | pacific grove
# Processing Record 3 of Set 3 | at-bashi
# Processing Record 4 of Set 3 | lebu
# Processing Record 5 of Set 3 | santa ana
# Processing Record 6 of Set 3 | qaqortoq
# Processing Record 7 of Set 3 | greenville
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | hithadhoo
# Processing Record 10 of Set 3 | guerrero negro
# Processing Record 11 of Set 3 | roma
# Processing Record 12 of Set 3 | bilibino
# Processing Record 13 of Set 3 | la foa
# Processing Record 14 of Set 3 | melekeok village
# Processing Record 15 of Set 3 | olonkinbyen
# Processing Record 16 of Set 3 | whitehorse
# Processing Record 17 of Set 3 | lazaro cardenas
# Processing Record 18 of Set 3 | college
# Processing Record 19 of Set 3 | oranjemund
# Processing Record 20 of Set 3 | villa gesell
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | tromso
# Processing Record 23 of Set 3 | cartagena
# Processing Record 24 of Set 3 | nanzhang chengguanzhen
# Processing Record 25 of Set 3 | maceio
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | iqaluit
# Processing Record 28 of Set 3 | mishelevka
# Processing Record 29 of Set 3 | enewetak
# Processing Record 30 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 31 of Set 3 | dudinka
# Processing Record 32 of Set 3 | ust-nera
# Processing Record 33 of Set 3 | antofagasta
# Processing Record 34 of Set 3 | bethel
# Processing Record 35 of Set 3 | beinamar
# Processing Record 36 of Set 3 | saint-joseph
# Processing Record 37 of Set 3 | nar'yan-mar
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | puerto deseado
# Processing Record 40 of Set 3 | tidjikja
# Processing Record 41 of Set 3 | gazli
# Processing Record 42 of Set 3 | dwarka
# Processing Record 43 of Set 3 | kapa'a
# Processing Record 44 of Set 3 | puerto baquerizo moreno
# Processing Record 45 of Set 3 | papatowai
# Processing Record 46 of Set 3 | cidreira
# Processing Record 47 of Set 3 | fort st. john
# Processing Record 48 of Set 3 | haflong
# Processing Record 49 of Set 3 | shenjiamen
# Processing Record 0 of Set 4 | kayangel
# Processing Record 1 of Set 4 | tanjung selor
# City not found. Skipping...
# Processing Record 2 of Set 4 | ushuaia
# Processing Record 3 of Set 4 | lata
# Processing Record 4 of Set 4 | callaway
# Processing Record 5 of Set 4 | jahanabad
# Processing Record 6 of Set 4 | magdagachi
# Processing Record 7 of Set 4 | sisimiut
# Processing Record 8 of Set 4 | zaozersk
# Processing Record 9 of Set 4 | holualoa
# Processing Record 10 of Set 4 | lorengau
# Processing Record 11 of Set 4 | nishinoomote
# Processing Record 12 of Set 4 | kuzovatovo
# Processing Record 13 of Set 4 | pyt-yakh
# Processing Record 14 of Set 4 | baker city
# Processing Record 15 of Set 4 | mogocha
# Processing Record 16 of Set 4 | kiiminki
# Processing Record 17 of Set 4 | kegen
# Processing Record 18 of Set 4 | amal
# Processing Record 19 of Set 4 | ambon
# Processing Record 20 of Set 4 | lautoka
# Processing Record 21 of Set 4 | jamestown
# Processing Record 22 of Set 4 | bernardo de irigoyen
# Processing Record 23 of Set 4 | ulsteinvik
# Processing Record 24 of Set 4 | pudozh
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | bubaque
# Processing Record 27 of Set 4 | ubinskoye
# Processing Record 28 of Set 4 | chui
# Processing Record 29 of Set 4 | queenstown
# Processing Record 30 of Set 4 | panuco
# Processing Record 31 of Set 4 | den burg
# Processing Record 32 of Set 4 | arauca
# Processing Record 33 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 34 of Set 4 | mount darwin
# Processing Record 35 of Set 4 | oroqen zizhiqi
# Processing Record 36 of Set 4 | shakhtersk
# Processing Record 37 of Set 4 | nuuk
# Processing Record 38 of Set 4 | harstad
# Processing Record 39 of Set 4 | tazovsky
# Processing Record 40 of Set 4 | the pas
# Processing Record 41 of Set 4 | saint-philippe
# Processing Record 42 of Set 4 | vadso
# Processing Record 43 of Set 4 | prado
# Processing Record 44 of Set 4 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 45 of Set 4 | santa rosa del sara
# City not found. Skipping...
# Processing Record 46 of Set 4 | espargos
# City not found. Skipping...
# Processing Record 47 of Set 4 | aykol
# City not found. Skipping...
# Processing Record 48 of Set 4 | hinton
# Processing Record 49 of Set 4 | santa terezinha
# Processing Record 0 of Set 5 | amstetten
# Processing Record 1 of Set 5 | luena
# Processing Record 2 of Set 5 | yantzaza
# Processing Record 3 of Set 5 | staryye ozinki
# Processing Record 4 of Set 5 | kayanza
# Processing Record 5 of Set 5 | qingyang
# Processing Record 6 of Set 5 | buncrana
# Processing Record 7 of Set 5 | port alfred
# Processing Record 8 of Set 5 | st. john's
# Processing Record 9 of Set 5 | vorgashor
# Processing Record 10 of Set 5 | tarashcha
# Processing Record 11 of Set 5 | utrik
# Processing Record 12 of Set 5 | mafinga
# Processing Record 13 of Set 5 | salamanca
# Processing Record 14 of Set 5 | olovyannaya
# Processing Record 15 of Set 5 | makueni boma
# Processing Record 16 of Set 5 | kudahuvadhoo
# Processing Record 17 of Set 5 | namibe
# Processing Record 18 of Set 5 | boradigah
# Processing Record 19 of Set 5 | laguna
# Processing Record 20 of Set 5 | chibougamau
# Processing Record 21 of Set 5 | port blair
# Processing Record 22 of Set 5 | brak
# Processing Record 23 of Set 5 | pytalovo
# Processing Record 24 of Set 5 | cadale
# Processing Record 25 of Set 5 | sinabang
# Processing Record 26 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 27 of Set 5 | broken hill
# Processing Record 28 of Set 5 | sandnessjoen
# Processing Record 29 of Set 5 | machico
# Processing Record 30 of Set 5 | amahai
# Processing Record 31 of Set 5 | douglas
# Processing Record 32 of Set 5 | cabo san lucas
# Processing Record 33 of Set 5 | mount gambier
# Processing Record 34 of Set 5 | sansanne-mango
# Processing Record 35 of Set 5 | batesville
# Processing Record 36 of Set 5 | uturoa
# Processing Record 37 of Set 5 | weno
# Processing Record 38 of Set 5 | kone
# Processing Record 39 of Set 5 | saint-pierre
# Processing Record 40 of Set 5 | naifaru
# Processing Record 41 of Set 5 | gadzhiyevo
# Processing Record 42 of Set 5 | yangambi
# Processing Record 43 of Set 5 | iquique
# Processing Record 44 of Set 5 | trashigang
# Processing Record 45 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 46 of Set 5 | corner brook
# Processing Record 47 of Set 5 | rio grande
# Processing Record 48 of Set 5 | arraial do cabo
# Processing Record 49 of Set 5 | al ghayzah
# Processing Record 0 of Set 6 | ostersund
# Processing Record 1 of Set 6 | piste
# Processing Record 2 of Set 6 | punta arenas
# Processing Record 3 of Set 6 | san severino marche
# Processing Record 4 of Set 6 | ancud
# Processing Record 5 of Set 6 | island harbour
# Processing Record 6 of Set 6 | parauapebas
# Processing Record 7 of Set 6 | beloyarskiy
# Processing Record 8 of Set 6 | faya-largeau
# Processing Record 9 of Set 6 | domoni
# Processing Record 10 of Set 6 | aripuana
# Processing Record 11 of Set 6 | attapeu
# Processing Record 12 of Set 6 | constantia
# Processing Record 13 of Set 6 | northam
# Processing Record 14 of Set 6 | port lincoln
# Processing Record 15 of Set 6 | caucasia
# Processing Record 16 of Set 6 | xicotencatl
# Processing Record 17 of Set 6 | san juan de miraflores
# Processing Record 18 of Set 6 | kerikeri
# Processing Record 19 of Set 6 | ebon
# Processing Record 20 of Set 6 | selkirk
# Processing Record 21 of Set 6 | tolanaro
# Processing Record 22 of Set 6 | vico del gargano
# Processing Record 23 of Set 6 | floro
# Processing Record 24 of Set 6 | 'alaqahdari dishu
# Processing Record 25 of Set 6 | nyrob
# Processing Record 26 of Set 6 | sabang
# Processing Record 27 of Set 6 | kayes
# Processing Record 28 of Set 6 | la grande
# Processing Record 29 of Set 6 | guilford
# Processing Record 30 of Set 6 | cole harbour
# Processing Record 31 of Set 6 | flin flon
# Processing Record 32 of Set 6 | atafu village
# Processing Record 33 of Set 6 | geraldton
# Processing Record 34 of Set 6 | namikupa
# Processing Record 35 of Set 6 | grand falls-windsor
# Processing Record 36 of Set 6 | argo
# Processing Record 37 of Set 6 | ballenger creek
# Processing Record 38 of Set 6 | happy valley-goose bay
# Processing Record 39 of Set 6 | nemuro
# Processing Record 40 of Set 6 | nova vicosa
# Processing Record 41 of Set 6 | hukumati azrah
# Processing Record 42 of Set 6 | minas de marcona
# Processing Record 43 of Set 6 | richards bay
# Processing Record 44 of Set 6 | santa cruz cabralia
# Processing Record 45 of Set 6 | karak city
# Processing Record 46 of Set 6 | daru
# Processing Record 47 of Set 6 | puigcerda
# Processing Record 48 of Set 6 | mwene-ditu
# Processing Record 49 of Set 6 | vilyuchinsk
# Processing Record 0 of Set 7 | baidoa
# Processing Record 1 of Set 7 | port moresby
# Processing Record 2 of Set 7 | isangel
# Processing Record 3 of Set 7 | aconibe
# Processing Record 4 of Set 7 | wawa
# Processing Record 5 of Set 7 | quixeramobim
# Processing Record 6 of Set 7 | dryden
# Processing Record 7 of Set 7 | khandyga
# Processing Record 8 of Set 7 | polyarnyy
# Processing Record 9 of Set 7 | amga
# Processing Record 10 of Set 7 | thames
# Processing Record 11 of Set 7 | bouznika
# Processing Record 12 of Set 7 | shenkursk
# Processing Record 13 of Set 7 | uyuni
# Processing Record 14 of Set 7 | hobe sound
# Processing Record 15 of Set 7 | lospalos
# Processing Record 16 of Set 7 | jabat
# Processing Record 17 of Set 7 | ivdel'
# Processing Record 18 of Set 7 | la'ie
# Processing Record 19 of Set 7 | new norfolk
# Processing Record 20 of Set 7 | nagqu
# Processing Record 21 of Set 7 | murzuq
# Processing Record 22 of Set 7 | duragan
# Processing Record 23 of Set 7 | zimmerman
# Processing Record 24 of Set 7 | gebeit
# Processing Record 25 of Set 7 | varkaus
# Processing Record 26 of Set 7 | vila velha
# Processing Record 27 of Set 7 | shingu
# Processing Record 28 of Set 7 | kelo
# Processing Record 29 of Set 7 | glace bay
# Processing Record 30 of Set 7 | aswan
# Processing Record 31 of Set 7 | hami
# Processing Record 32 of Set 7 | dodge city
# Processing Record 33 of Set 7 | port-gentil
# Processing Record 34 of Set 7 | sambava
# Processing Record 35 of Set 7 | san patricio
# Processing Record 36 of Set 7 | horta
# Processing Record 37 of Set 7 | pontes e lacerda
# Processing Record 38 of Set 7 | saipan
# Processing Record 39 of Set 7 | siran
# Processing Record 40 of Set 7 | ixtapa
# Processing Record 41 of Set 7 | talara
# Processing Record 42 of Set 7 | pont-l'abbe
# City not found. Skipping...
# Processing Record 43 of Set 7 | darhan
# Processing Record 44 of Set 7 | looe
# Processing Record 45 of Set 7 | midvagur
# Processing Record 46 of Set 7 | turiacu
# Processing Record 47 of Set 7 | georgetown
# Processing Record 48 of Set 7 | nelson bay
# Processing Record 49 of Set 7 | larkird
# Processing Record 0 of Set 8 | tete
# Processing Record 1 of Set 8 | port elizabeth
# Processing Record 2 of Set 8 | eyl
# Processing Record 3 of Set 8 | qa'en
# Processing Record 4 of Set 8 | midar
# Processing Record 5 of Set 8 | luanda
# Processing Record 6 of Set 8 | aoulef
# Processing Record 7 of Set 8 | paphos
# Processing Record 8 of Set 8 | alenquer
# Processing Record 9 of Set 8 | zuni pueblo
# Processing Record 10 of Set 8 | aykhal
# Processing Record 11 of Set 8 | gizo
# Processing Record 12 of Set 8 | sonsorol village
# City not found. Skipping...
# Processing Record 13 of Set 8 | kavaratti
# Processing Record 14 of Set 8 | axim
# Processing Record 15 of Set 8 | kodinar
# Processing Record 16 of Set 8 | crucecita
# Processing Record 17 of Set 8 | airdrie
# Processing Record 18 of Set 8 | alofi
# Processing Record 19 of Set 8 | kristiansund
# Processing Record 20 of Set 8 | las palmas de gran canaria
# Processing Record 21 of Set 8 | sault ste. marie
# Processing Record 22 of Set 8 | akjoujt
# Processing Record 23 of Set 8 | burlington
# Processing Record 24 of Set 8 | biloela
# Processing Record 25 of Set 8 | taltal
# Processing Record 26 of Set 8 | saldanha
# Processing Record 27 of Set 8 | starobin
# Processing Record 28 of Set 8 | maysville
# Processing Record 29 of Set 8 | fale old settlement
# Processing Record 30 of Set 8 | rongelap
# Processing Record 31 of Set 8 | chernushka
# Processing Record 32 of Set 8 | walvis bay
# Processing Record 33 of Set 8 | codrington
# Processing Record 34 of Set 8 | port douglas
# Processing Record 35 of Set 8 | aban
# Processing Record 36 of Set 8 | sishilichengzi
# City not found. Skipping...
# Processing Record 37 of Set 8 | mustafakemalpasa
# Processing Record 38 of Set 8 | lompoc
# Processing Record 39 of Set 8 | uzice
# Processing Record 40 of Set 8 | cooper's town
# Processing Record 41 of Set 8 | portland
# Processing Record 42 of Set 8 | sylvan lake
# Processing Record 43 of Set 8 | ganshui
# Processing Record 44 of Set 8 | ola
# Processing Record 45 of Set 8 | berastagi
# Processing Record 46 of Set 8 | astrakhan
# Processing Record 47 of Set 8 | sandy point town
# Processing Record 48 of Set 8 | alice springs
# Processing Record 49 of Set 8 | roxas
# Processing Record 0 of Set 9 | nabari
# Processing Record 1 of Set 9 | el calafate
# Processing Record 2 of Set 9 | susuman
# Processing Record 3 of Set 9 | ometepec
# Processing Record 4 of Set 9 | kapuskasing
# Processing Record 5 of Set 9 | souillac
# Processing Record 6 of Set 9 | siyabuswa
# Processing Record 7 of Set 9 | palangkaraya
# Processing Record 8 of Set 9 | lesogorsk
# Processing Record 9 of Set 9 | howrah
# Processing Record 10 of Set 9 | petauke
# Processing Record 11 of Set 9 | wanning
# Processing Record 12 of Set 9 | katsuren-haebaru
# Processing Record 13 of Set 9 | villa huidobro
# Processing Record 14 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 15 of Set 9 | quellon
# Processing Record 16 of Set 9 | mugia
# Processing Record 17 of Set 9 | kirovskaya
# Processing Record 18 of Set 9 | mersa matruh
# Processing Record 19 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 20 of Set 9 | la rinconada
# Processing Record 21 of Set 9 | zangguy
# City not found. Skipping...
# Processing Record 22 of Set 9 | port saint john's
# Processing Record 23 of Set 9 | la passe
# Processing Record 24 of Set 9 | haiku-pauwela
# Processing Record 25 of Set 9 | ras al khaimah city
# Processing Record 26 of Set 9 | nuriootpa
# Processing Record 27 of Set 9 | barah
# Processing Record 28 of Set 9 | avesta
# Processing Record 29 of Set 9 | calenzano
# Processing Record 30 of Set 9 | kabalo
# Processing Record 31 of Set 9 | banda aceh
# Processing Record 32 of Set 9 | slavgorod
# Processing Record 33 of Set 9 | yalta
# Processing Record 34 of Set 9 | coronel moldes
# Processing Record 35 of Set 9 | nuku'alofa
# Processing Record 36 of Set 9 | nhandeara
# Processing Record 37 of Set 9 | altamont
# Processing Record 38 of Set 9 | mingshui
# Processing Record 39 of Set 9 | bikenibeu village
# Processing Record 40 of Set 9 | novodvinsk
# Processing Record 41 of Set 9 | katsuura
# Processing Record 42 of Set 9 | kearney
# Processing Record 43 of Set 9 | fort bragg
# Processing Record 44 of Set 9 | yabelo
# Processing Record 45 of Set 9 | berbera
# Processing Record 46 of Set 9 | gold camp
# Processing Record 47 of Set 9 | puerto armuelles
# Processing Record 48 of Set 9 | greymouth
# Processing Record 49 of Set 9 | taiyuan
# Processing Record 0 of Set 10 | piacabucu
# Processing Record 1 of Set 10 | nizhnesortymskiy
# Processing Record 2 of Set 10 | skovorodino
# Processing Record 3 of Set 10 | shimoda
# Processing Record 4 of Set 10 | magistral'nyy
# Processing Record 5 of Set 10 | broome
# Processing Record 6 of Set 10 | san rafael del sur
# Processing Record 7 of Set 10 | mount pearl
# Processing Record 8 of Set 10 | viedma
# Processing Record 9 of Set 10 | quibor
# Processing Record 10 of Set 10 | vikulovo
# Processing Record 11 of Set 10 | ayios konstandinos
# Processing Record 12 of Set 10 | zhirnovsk
# Processing Record 13 of Set 10 | bonthe
# Processing Record 14 of Set 10 | touros
# Processing Record 15 of Set 10 | thinadhoo
# Processing Record 16 of Set 10 | thunder bay
# Processing Record 17 of Set 10 | chimore
# Processing Record 18 of Set 10 | maintirano
# Processing Record 19 of Set 10 | yarmouth
# Processing Record 20 of Set 10 | carutapera
# Processing Record 21 of Set 10 | pangai
# Processing Record 22 of Set 10 | taroa
# Processing Record 23 of Set 10 | mezgor'e
# City not found. Skipping...
# Processing Record 24 of Set 10 | laredo
# Processing Record 25 of Set 10 | cordele
# Processing Record 26 of Set 10 | cartagena del chaira
# Processing Record 27 of Set 10 | namdrik
# Processing Record 28 of Set 10 | seydi
# Processing Record 29 of Set 10 | guarapari
# Processing Record 30 of Set 10 | beckley
# Processing Record 31 of Set 10 | dayapar
# City not found. Skipping...
# Processing Record 32 of Set 10 | creel
# Processing Record 33 of Set 10 | princeville
# Processing Record 34 of Set 10 | levuka
# Processing Record 35 of Set 10 | luderitz
# Processing Record 36 of Set 10 | malasila
# Processing Record 37 of Set 10 | guiyang
# Processing Record 38 of Set 10 | fisterra
# Processing Record 39 of Set 10 | ust'-kulom
# Processing Record 40 of Set 10 | bel ombre
# Processing Record 41 of Set 10 | pundong
# Processing Record 42 of Set 10 | devils lake
# Processing Record 43 of Set 10 | koungheul
# Processing Record 44 of Set 10 | xinzhi
# Processing Record 45 of Set 10 | tongliao
# Processing Record 46 of Set 10 | mahdia
# Processing Record 47 of Set 10 | arroyito
# Processing Record 48 of Set 10 | tarakan
# Processing Record 49 of Set 10 | karratha
# Processing Record 0 of Set 11 | egersund
# Processing Record 1 of Set 11 | acarau
# Processing Record 2 of Set 11 | freetown
# Processing Record 3 of Set 11 | trincomalee
# Processing Record 4 of Set 11 | carbonear
# Processing Record 5 of Set 11 | kailua-kona
# Processing Record 6 of Set 11 | singarayakonda
# Processing Record 7 of Set 11 | masterton
# Processing Record 8 of Set 11 | batticaloa
# Processing Record 9 of Set 11 | coyhaique
# Processing Record 10 of Set 11 | sovetskaya gavan'
# Processing Record 11 of Set 11 | puerto ayacucho
# Processing Record 12 of Set 11 | claveria
# Processing Record 13 of Set 11 | kamaishi
# Processing Record 14 of Set 11 | tofol
# Processing Record 15 of Set 11 | dipayal
# Processing Record 16 of Set 11 | tobi village
# City not found. Skipping...
# Processing Record 17 of Set 11 | ulanhot
# Processing Record 18 of Set 11 | boende
# Processing Record 19 of Set 11 | alesund
# Processing Record 20 of Set 11 | dul'durga
# Processing Record 21 of Set 11 | turochak
# Processing Record 22 of Set 11 | ponta delgada
# Processing Record 23 of Set 11 | undurkhaan
# Processing Record 24 of Set 11 | pasuquin
# Processing Record 25 of Set 11 | mushie
# Processing Record 26 of Set 11 | lakota
# Processing Record 27 of Set 11 | naze
# Processing Record 28 of Set 11 | halifax
# Processing Record 29 of Set 11 | gaiman
# Processing Record 30 of Set 11 | fortuna
# Processing Record 31 of Set 11 | anton lizardo
# Processing Record 32 of Set 11 | mezhdurechenskiy
# Processing Record 33 of Set 11 | laojunmiao
# Processing Record 34 of Set 11 | ceres
# Processing Record 35 of Set 11 | eduardo castex
# Processing Record 36 of Set 11 | okhotsk
# Processing Record 37 of Set 11 | preobrazheniye
# Processing Record 38 of Set 11 | tirumullaivasal
# Processing Record 39 of Set 11 | burela de cabo
# Processing Record 40 of Set 11 | nea alikarnassos
# Processing Record 41 of Set 11 | tsengel
# Processing Record 42 of Set 11 | balykshi
# Processing Record 43 of Set 11 | labytnangi
# Processing Record 44 of Set 11 | ha'il
# Processing Record 45 of Set 11 | bedesa
# Processing Record 46 of Set 11 | miracema do tocantins
# Processing Record 47 of Set 11 | igarka
# Processing Record 48 of Set 11 | zabaykal'sk
# Processing Record 49 of Set 11 | bengkulu
# Processing Record 0 of Set 12 | sake
# Processing Record 1 of Set 12 | sampit
# Processing Record 2 of Set 12 | calvi
# Processing Record 3 of Set 12 | naduvattam
# Processing Record 4 of Set 12 | lent'ekhi
# Processing Record 5 of Set 12 | sand springs
# Processing Record 6 of Set 12 | fort irwin
# Processing Record 7 of Set 12 | yamada
# Processing Record 8 of Set 12 | taoudenni
# Processing Record 9 of Set 12 | dhuusamarreeb
# Processing Record 10 of Set 12 | rio gallegos
# Processing Record 11 of Set 12 | tsiombe
# Processing Record 12 of Set 12 | cambria
# Processing Record 13 of Set 12 | huangmei
# Processing Record 14 of Set 12 | fort mcmurray
# Processing Record 15 of Set 12 | panevezys
# Processing Record 16 of Set 12 | ceerigaabo
# Processing Record 17 of Set 12 | malangawa
# Processing Record 18 of Set 12 | melfort
# Processing Record 19 of Set 12 | nybro
# Processing Record 20 of Set 12 | tura
# Processing Record 21 of Set 12 | korla
# Processing Record 22 of Set 12 | dickinson
# Processing Record 23 of Set 12 | zambezi
# Processing Record 24 of Set 12 | concepcion
# Processing Record 25 of Set 12 | bria
# Processing Record 26 of Set 12 | auki
# Processing Record 27 of Set 12 | hilo
# Processing Record 28 of Set 12 | morant bay
# Processing Record 29 of Set 12 | isle of lewis
# City not found. Skipping...
# Processing Record 30 of Set 12 | aral
# Processing Record 31 of Set 12 | atherton
# Processing Record 32 of Set 12 | brisas de zicatela
# Processing Record 33 of Set 12 | khark
# Processing Record 34 of Set 12 | kirkwall
# Processing Record 35 of Set 12 | lihue
# Processing Record 36 of Set 12 | kiunga
# Processing Record 37 of Set 12 | novyy urgal
# Processing Record 38 of Set 12 | sterling
# Processing Record 39 of Set 12 | mangrol
# Processing Record 40 of Set 12 | rio branco
# Processing Record 41 of Set 12 | diapaga
# Processing Record 42 of Set 12 | prince edward
# Processing Record 43 of Set 12 | naryn
# Processing Record 44 of Set 12 | barcelos
# Processing Record 45 of Set 12 | port sudan
# Processing Record 46 of Set 12 | san andres
# Processing Record 47 of Set 12 | joshimath
# Processing Record 48 of Set 12 | portoferraio
# Processing Record 49 of Set 12 | labuan
# Processing Record 0 of Set 13 | rafsanjan
# Processing Record 1 of Set 13 | luoyang
# Processing Record 2 of Set 13 | kolonia
# Processing Record 3 of Set 13 | bayanhongor
# Processing Record 4 of Set 13 | zhangye
# Processing Record 5 of Set 13 | itoman
# Processing Record 6 of Set 13 | sorong
# Processing Record 7 of Set 13 | pangody
# Processing Record 8 of Set 13 | palmer
# Processing Record 9 of Set 13 | coelho neto
# Processing Record 10 of Set 13 | petukhovo
# Processing Record 11 of Set 13 | dubbo
# Processing Record 12 of Set 13 | abepura
# Processing Record 13 of Set 13 | moju
# Processing Record 14 of Set 13 | neiafu
# Processing Record 15 of Set 13 | xilin hot
# Processing Record 16 of Set 13 | estevan
# Processing Record 17 of Set 13 | callao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          591
# Lat           591
# Lng           591
# Max Temp      591
# Humidity      591
# Cloudiness    591
# Wind Speed    591
# Country       591
# Date          591
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat       Lng  Max Temp  Humidity  \
# 0            port-aux-francais -49.3500   70.2167      1.31        55
# 1       hawaiian paradise park  19.5933 -154.9731     22.63        90
# 2                   doganhisar  38.1463   31.6765     21.12        50
# 3  edinburgh of the seven seas -37.0676  -12.3116     15.34        79
# 4               puerto natales -51.7236  -72.4875     -4.76        90
#
#    Cloudiness  Wind Speed Country        Date
# 0          91        7.88      TF  1688899377
# 1         100        2.06      US  1688899377
# 2          51        6.07      TR  1688899377
# 3         100       10.26      SH  1688899378
# 4           9        1.15      CL  1688899378

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                  port-aux-francais -49.3500   70.2167      1.31        55
# 1             hawaiian paradise park  19.5933 -154.9731     22.63        90
# 2                         doganhisar  38.1463   31.6765     21.12        50
# 3        edinburgh of the seven seas -37.0676  -12.3116     15.34        79
# 4                     puerto natales -51.7236  -72.4875     -4.76        90
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                91        7.88      TF  1688899377
# 1               100        2.06      US  1688899377
# 2                51        6.07      TR  1688899377
# 3               100       10.26      SH  1688899378
# 4                 9        1.15      CL  1688899378

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'])

# Incorporate the other graph properties
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Max Temperature vs. Latitude')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'])

# Incorporate the other graph properties
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Humidity vs. Latitude')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'])

# Incorporate the other graph properties
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Cloudiness vs. Latitude')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'])

# Incorporate the other graph properties
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Wind Speed vs. Latitude')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
def linreg(x, y):
    #initial scatter plot
    plt.scatter(x, y)
    
    #calculates regression line
    r_slope, r_int, r_r, r_p, r_std_err = linregress(x, y)
    r_fit = r_slope * x + r_int
    
    #prints the r value
    print(f'The r-value is: {r_r}')
    plt.plot(x, r_fit, color='red')
    
    #displays the regression equation, fixed placement needs work
    plt.text(0, 5, f'y={r_slope:.2f}*x+{r_int:.2f}')

# %%
def linregpandas(df, x, y):
    df.plot(kind='scatter', x = x, y = y)
    
    #calculates regression line
    r_slope, r_int, r_r, r_p, r_std_err = linregress(df[x], df[y])
    r_fit = r_slope * df[x] + r_int
    
    #prints the r value
    print(f'The r-value is: {r_r}')
    plt.plot(df[x], r_fit, color='red')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1        hawaiian paradise park  19.5933 -154.9731     22.63        90
# 2                    doganhisar  38.1463   31.6765     21.12        50
# 6                         mejit  10.2753  170.8646     28.24        79
# 7                 chakradharpur  22.7000   85.6333     33.15        57
# 8                        harper   4.3750   -7.7169     26.42        81
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1               100        2.06      US  1688899377
# 2                51        6.07      TR  1688899377
# 6               100        8.51      MH  1688899378
# 7                93        4.10      IN  1688899379
# 8                67        4.92      LR  1688899379

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0                  port-aux-francais -49.3500  70.2167      1.31        55
# 3        edinburgh of the seven seas -37.0676 -12.3116     15.34        79
# 4                     puerto natales -51.7236 -72.4875     -4.76        90
# 5                          grytviken -54.2811 -36.5092     -5.96        83
# 10                        bredasdorp -34.5322  20.0403     12.49        68
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                91        7.88      TF  1688899377
# 3               100       10.26      SH  1688899378
# 4                 9        1.15      CL  1688899378
# 5                39        5.24      GS  1688899378
# 10               43        6.84      ZA  1688899379

# %%
linregpandas(northern_hemi_df, 'Lat', 'Max Temp')
# Out:
# The r-value is: -0.5661903671576889

# %%
# Linear regression on Northern Hemisphere
linreg(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])

plt.xlabel('Latitude')
plt.ylabel('Max Temp')

plt.show()
# Out:
# The r-value is: -0.5661903671576889

# %%
# Linear regression on Southern Hemisphere
linreg(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])

plt.xlabel('Latitude')
plt.ylabel('Max Temp')

plt.show()

# %%
print('We can see that max temp increases as we appraoch Lat=0 in both the north and south hemispherres.')

# %%
# Northern Hemisphere
linreg(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])

plt.xlabel('Latitude')
plt.ylabel('Humidity')

plt.show()

# %%
# Southern Hemisphere
linreg(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])

plt.xlabel('Latitude')
plt.ylabel('Humidity')

plt.show()

# %%
print('The R values tell us there is very weak to no correlation ebwteen latitude and humidity.')

# %%
# Northern Hemisphere
linreg(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

plt.show()

# %%
# Southern Hemisphere
linreg(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

plt.show()

# %%
print('The R value indicates there is very low to no correlation between latitiude and cloudiness.')

# %%
# Northern Hemisphere
linreg(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

plt.show()

# %%
# Southern Hemisphere
linreg(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

plt.show()

# %%
print('The R value indicates there is a weak positive correlation bwtween latitude and wind speed as you approach the equator.')
